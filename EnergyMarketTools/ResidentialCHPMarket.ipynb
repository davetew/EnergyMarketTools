# %% [markdown]
# # Residential CHP Market Analysis

# %%
"""Set up python environment for data analysis"""
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import pickle

mpl.rcParams['figure.figsize'] = [8.0, 6.0]
mpl.rcParams['figure.dpi'] = 80
mpl.rcParams['savefig.dpi'] = 100

mpl.rcParams['font.size'] = 12
mpl.rcParams['legend.fontsize'] = 'xx-small'
mpl.rcParams['figure.titlesize'] = 'medium'

from DGMarketStudy import MarketStudy

# %%
"""Execute Residential CHP Market Assessment"""

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

sector = 'RES'
year = 2016
region = None
study_name = 'ResMarketStudy_2016.dat'
          
US_Market_Eval = MarketStudy(Regions=states, Years=[year], Sectors=[sector], 
                     x_param_name='electric_efficiency',
                     x_param_values=np.linspace(0.25,0.8,100),
                     y_param_name='installed_price_dol_W',
                     y_param_values=np.logspace(np.log10(0.2),np.log10(5),100),
                     electric_efficiency = 0.4,
                     thermal_efficiency = '(1-electric_efficiency)/2',
                     installed_price_dol_W = 3,
                     maint_cost_dol_kWh = 0.02,
                     life_yrs = 20,
                     elec_capacity_utilization = 0.80,
                     therm_capacity_utilization = 0.50,
                     baseline_thermal_efficiency = 0.9,
                     inflation_rate = 0.02,
                     discount_rate = 0.15,
                     grid_baseline_elec_efficiency=0.34)
# Out:
# Downloading SEDS.ESRCD.AL.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Alabama
# Downloading SEDS.ESRCP.AL.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Alabama
# Downloading SEDS.NGRCD.AL.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Alabama
# Downloading SEDS.ESRCD.AK.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Alaska
# Downloading SEDS.ESRCP.AK.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Alaska
# Downloading SEDS.NGRCD.AK.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Alaska
# Downloading SEDS.ESRCD.AZ.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Arizona
# Downloading SEDS.ESRCP.AZ.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Arizona
# Downloading SEDS.NGRCD.AZ.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Arizona
# Downloading SEDS.ESRCD.AR.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Arkansas
# Downloading SEDS.ESRCP.AR.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Arkansas
# Downloading SEDS.NGRCD.AR.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Arkansas
# Downloading SEDS.ESRCD.CA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, California
# Downloading SEDS.ESRCP.CA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, California
# Downloading SEDS.NGRCD.CA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), California
# Downloading SEDS.ESRCD.CO.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Colorado
# Downloading SEDS.ESRCP.CO.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Colorado
# Downloading SEDS.NGRCD.CO.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Colorado
# Downloading SEDS.ESRCD.CT.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Connecticut
# Downloading SEDS.ESRCP.CT.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Connecticut
# Downloading SEDS.NGRCD.CT.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Connecticut
# Downloading SEDS.ESRCD.DC.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, District of Columbia
# Downloading SEDS.ESRCP.DC.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, District of Columbia
# Downloading SEDS.NGRCD.DC.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), District of Columbia
# Downloading SEDS.ESRCD.DE.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Delaware
# Downloading SEDS.ESRCP.DE.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Delaware
# Downloading SEDS.NGRCD.DE.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Delaware
# Downloading SEDS.ESRCD.FL.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Florida
# Downloading SEDS.ESRCP.FL.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Florida
# Downloading SEDS.NGRCD.FL.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Florida
# Downloading SEDS.ESRCD.GA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Georgia
# Downloading SEDS.ESRCP.GA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Georgia
# Downloading SEDS.NGRCD.GA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Georgia
# Downloading SEDS.ESRCD.HI.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Hawaii
# Downloading SEDS.ESRCP.HI.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Hawaii
# Downloading SEDS.NGRCD.HI.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Hawaii
# Downloading SEDS.ESRCD.ID.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Idaho
# Downloading SEDS.ESRCP.ID.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Idaho
# Downloading SEDS.NGRCD.ID.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Idaho
# Downloading SEDS.ESRCD.IL.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Illinois
# Downloading SEDS.ESRCP.IL.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Illinois
# Downloading SEDS.NGRCD.IL.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Illinois
# Downloading SEDS.ESRCD.IN.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Indiana
# Downloading SEDS.ESRCP.IN.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Indiana
# Downloading SEDS.NGRCD.IN.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Indiana
# Downloading SEDS.ESRCD.IA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Iowa
# Downloading SEDS.ESRCP.IA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Iowa
# Downloading SEDS.NGRCD.IA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Iowa
# Downloading SEDS.ESRCD.KS.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Kansas
# Downloading SEDS.ESRCP.KS.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Kansas
# Downloading SEDS.NGRCD.KS.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Kansas
# Downloading SEDS.ESRCD.KY.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Kentucky
# Downloading SEDS.ESRCP.KY.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Kentucky
# Downloading SEDS.NGRCD.KY.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Kentucky
# Downloading SEDS.ESRCD.LA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Louisiana
# Downloading SEDS.ESRCP.LA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Louisiana
# Downloading SEDS.NGRCD.LA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Louisiana
# Downloading SEDS.ESRCD.ME.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Maine
# Downloading SEDS.ESRCP.ME.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Maine
# Downloading SEDS.NGRCD.ME.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Maine
# Downloading SEDS.ESRCD.MD.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Maryland
# Downloading SEDS.ESRCP.MD.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Maryland
# Downloading SEDS.NGRCD.MD.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Maryland
# Downloading SEDS.ESRCD.MA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Massachusetts
# Downloading SEDS.ESRCP.MA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Massachusetts
# Downloading SEDS.NGRCD.MA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Massachusetts
# Downloading SEDS.ESRCD.MI.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Michigan
# Downloading SEDS.ESRCP.MI.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Michigan
# Downloading SEDS.NGRCD.MI.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Michigan
# Downloading SEDS.ESRCD.MN.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Minnesota
# Downloading SEDS.ESRCP.MN.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Minnesota
# Downloading SEDS.NGRCD.MN.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Minnesota
# Downloading SEDS.ESRCD.MS.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Mississippi
# Downloading SEDS.ESRCP.MS.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Mississippi
# Downloading SEDS.NGRCD.MS.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Mississippi
# Downloading SEDS.ESRCD.MO.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Missouri
# Downloading SEDS.ESRCP.MO.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Missouri
# Downloading SEDS.NGRCD.MO.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Missouri
# Downloading SEDS.ESRCD.MT.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Montana
# Downloading SEDS.ESRCP.MT.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Montana
# Downloading SEDS.NGRCD.MT.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Montana
# Downloading SEDS.ESRCD.NE.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Nebraska
# Downloading SEDS.ESRCP.NE.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Nebraska
# Downloading SEDS.NGRCD.NE.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Nebraska
# Downloading SEDS.ESRCD.NV.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Nevada
# Downloading SEDS.ESRCP.NV.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Nevada
# Downloading SEDS.NGRCD.NV.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Nevada
# Downloading SEDS.ESRCD.NH.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, New Hampshire
# Downloading SEDS.ESRCP.NH.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, New Hampshire
# Downloading SEDS.NGRCD.NH.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), New Hampshire
# Downloading SEDS.ESRCD.NJ.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, New Jersey
# Downloading SEDS.ESRCP.NJ.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, New Jersey
# Downloading SEDS.NGRCD.NJ.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), New Jersey
# Downloading SEDS.ESRCD.NM.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, New Mexico
# Downloading SEDS.ESRCP.NM.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, New Mexico
# Downloading SEDS.NGRCD.NM.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), New Mexico
# Downloading SEDS.ESRCD.NY.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, New York
# Downloading SEDS.ESRCP.NY.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, New York
# Downloading SEDS.NGRCD.NY.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), New York
# Downloading SEDS.ESRCD.NC.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, North Carolina
# Downloading SEDS.ESRCP.NC.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, North Carolina
# Downloading SEDS.NGRCD.NC.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), North Carolina
# Downloading SEDS.ESRCD.ND.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, North Dakota
# Downloading SEDS.ESRCP.ND.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, North Dakota
# Downloading SEDS.NGRCD.ND.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), North Dakota
# Downloading SEDS.ESRCD.OH.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Ohio
# Downloading SEDS.ESRCP.OH.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Ohio
# Downloading SEDS.NGRCD.OH.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Ohio
# Downloading SEDS.ESRCD.OK.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Oklahoma
# Downloading SEDS.ESRCP.OK.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Oklahoma
# Downloading SEDS.NGRCD.OK.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Oklahoma
# Downloading SEDS.ESRCD.OR.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Oregon
# Downloading SEDS.ESRCP.OR.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Oregon
# Downloading SEDS.NGRCD.OR.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Oregon
# Downloading SEDS.ESRCD.PA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Pennsylvania
# Downloading SEDS.ESRCP.PA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Pennsylvania
# Downloading SEDS.NGRCD.PA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Pennsylvania
# Downloading SEDS.ESRCD.RI.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Rhode Island
# Downloading SEDS.ESRCP.RI.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Rhode Island
# Downloading SEDS.NGRCD.RI.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Rhode Island
# Downloading SEDS.ESRCD.SC.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, South Carolina
# Downloading SEDS.ESRCP.SC.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, South Carolina
# Downloading SEDS.NGRCD.SC.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), South Carolina
# Downloading SEDS.ESRCD.SD.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, South Dakota
# Downloading SEDS.ESRCP.SD.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, South Dakota
# Downloading SEDS.NGRCD.SD.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), South Dakota
# Downloading SEDS.ESRCD.TN.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Tennessee
# Downloading SEDS.ESRCP.TN.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Tennessee
# Downloading SEDS.NGRCD.TN.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Tennessee
# Downloading SEDS.ESRCD.TX.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Texas
# Downloading SEDS.ESRCP.TX.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Texas
# Downloading SEDS.NGRCD.TX.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Texas
# Downloading SEDS.ESRCD.UT.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Utah
# Downloading SEDS.ESRCP.UT.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Utah
# Downloading SEDS.NGRCD.UT.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Utah
# Downloading SEDS.ESRCD.VT.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Vermont
# Downloading SEDS.ESRCP.VT.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Vermont
# Downloading SEDS.NGRCD.VT.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Vermont
# Downloading SEDS.ESRCD.VA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Virginia
# Downloading SEDS.ESRCP.VA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Virginia
# Downloading SEDS.NGRCD.VA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Virginia
# Downloading SEDS.ESRCD.WA.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Washington
# Downloading SEDS.ESRCP.WA.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Washington
# Downloading SEDS.NGRCD.WA.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Washington
# Downloading SEDS.ESRCD.WV.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, West Virginia
# Downloading SEDS.ESRCP.WV.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, West Virginia
# Downloading SEDS.NGRCD.WV.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), West Virginia
# Downloading SEDS.ESRCD.WI.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Wisconsin
# Downloading SEDS.ESRCP.WI.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Wisconsin
# Downloading SEDS.NGRCD.WI.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Wisconsin
# Downloading SEDS.ESRCD.WY.A from the EIA.
#    Successfully retrieved--> Electricity price in the residential sector, Wyoming
# Downloading SEDS.ESRCP.WY.A from the EIA.
#    Successfully retrieved--> Electricity consumed by (i.e., sold to) the residential sector, Wyoming
# Downloading SEDS.NGRCD.WY.A from the EIA.
#    Successfully retrieved--> Natural gas price in the residential sector (including supplemental gaseous fuels), Wyoming

# %%
pickle.dump(US_Market_Eval,open(study_name,'wb'))

region = 'CA'
US_Market_Eval.contour_plot(sector=sector,year=year,region=region,metric='PB_yrs')
US_Market_Eval.contour_plot(sector=sector,year=year,region=region,metric='LCOE_dol_kWh')
US_Market_Eval.contour_plot(sector=sector,year=year,region=region,metric='MaxMarketPen')
US_Market_Eval.contour_plot(sector=sector,year=year,region=region,metric='NPV_dol_kWh')
US_Market_Eval.contour_plot(sector=sector,year=year,region=region,metric='TotalMarketPen')
US_Market_Eval.contour_plot(sector=sector,year=year,region=region,metric='PrimaryEnergySavings_Quads')
# Out:
# (<matplotlib.figure.Figure at 0x11b910c50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1101c6550>)
